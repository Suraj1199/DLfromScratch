# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import datasets
from sklearn.utils import Bunch
import tensorflow as tf

# %%
np.set_printoptions(precision=4, threshold=15)

# %% [markdown]
# ## Dataset

# %%
(X_train, y_train), (X_test, y_test)= tf.keras.datasets.boston_housing.load_data()
print("X_train shape : ", X_train.shape)
print("X_test shape : ", X_test.shape)
print("y_train shape : ", y_train.shape)
print("y_test shape : ", y_test.shape)
# Out:
# X_train shape :  (404, 13)
# X_test shape :  (102, 13)
# y_train shape :  (404,)
# y_test shape :  (102,)

# %%
plt.figure(figsize=(20, 25))
for i in range(13):
    plt.subplot(5, 3, i + 1)
    plt.scatter(X_train[:, i], y_train)
    plt.xlabel(f'X{i + 1}')
    plt.ylabel('y')

# %% [markdown]
# Drop features

# %%
features = [0, 2, 4, 5, 6, 7, 10, 11, 12]
X_train = X_train[:, features]
X_test = X_test[:, features]
print("X_train shape : ", X_train.shape)
print("X_test shape : ", X_test.shape)
print("y_train shape : ", y_train.shape)
print("y_test shape : ", y_test.shape)
# Out:
# X_train shape :  (404, 9)
# X_test shape :  (102, 9)
# y_train shape :  (404,)
# y_test shape :  (102,)

# %% [markdown]
# ## Multiple Linear Regression Model

# %%
class MultipleLinearRegressor:
    def __init__(self,n_features=None, weights=None, normalize=True):
        self.__n_features = n_features
        self.weights = weights if weights else np.random.randn(self.__n_features + 1) 
        self.__normalize = normalize
        self.__scaling_params = (0, 1)
        self.loss_per_epochs = []
           
    def __transform(self, X):
        if self.__normalize:
            mu, s = self.__scaling_params
            X = (X - mu) / (s + 1e-9)
        return np.vstack([np.ones(X.shape[0]), X.T])
        
    def fit(self, X, y, epochs=1, batch_size=None, alpha=0.001, verbose=True):
        self.__scaling_params = (X.mean(axis=0), X.std(axis=0))
        X = self.__transform(X)
        losses = []
        for i in range(epochs):
            y_pred = self.weights.T @ X
            J = 0.5 * np.mean(np.square(y - y_pred))
            self.weights -= alpha * np.mean((y_pred - y) * X, axis=1)
            losses.append(J)
            if verbose:
                print(f'Epoch {i+1}/{epochs}\n{X.shape[-1]}/{X.shape[-1]} [==============] : loss = {J}')
        self.loss_per_epochs = losses
        
    def predict(self, X):
        return self.weights.T @ self.__transform(X)
    
    def evaluate(self, X, y):
        y_pred = self.predict(X)
        J = 0.5 * np.mean(np.square(y - y_pred))
        return J
    
    def get_weights(self, return_scaling_params=False):
        """returns weights as a dict object with keys - `weights` and `bias`"""
        model_weights = {'weights' : self.weights[1:], 'bias' : self.weights[0]}
        if return_scaling_params:
            model_weights['scaling_mean'], model_weights['scaling_std'] = self.__scaling_params
        return model_weights

# %% [markdown]
# ## Training

# %%
model = MultipleLinearRegressor(n_features=9)

# %%
model.fit(X_train, y_train, epochs=200, alpha=0.05)
# Out:
# Epoch 1/200
# 404/404 [==============] : loss = 383.12883196374344
# Epoch 2/200
# 404/404 [==============] : loss = 332.11059605328916
# Epoch 3/200
# 404/404 [==============] : loss = 292.1059940848635
# Epoch 4/200
# 404/404 [==============] : loss = 259.5968235256738
# Epoch 5/200
# 404/404 [==============] : loss = 232.39795788504392
# Epoch 6/200
# 404/404 [==============] : loss = 209.12624680066656
# Epoch 7/200
# 404/404 [==============] : loss = 188.88373174816812
# Epoch 8/200
# 404/404 [==============] : loss = 171.06842227680707
# Epoch 9/200
# 404/404 [==============] : loss = 155.26102302467697
# Epoch 10/200
# 404/404 [==============] : loss = 141.15690674455362
# Epoch 11/200
# 404/404 [==============] : loss = 128.52506342397163
# Epoch 12/200
# 404/404 [==============] : loss = 117.18315240809446
# Epoch 13/200
# 404/404 [==============] : loss = 106.98218461887062
# Epoch 14/200
# 404/404 [==============] : loss = 97.79697971383726
# Epoch 15/200
# 404/404 [==============] : loss = 89.52010054666812
# Epoch 16/200
# 404/404 [==============] : loss = 82.05789414481366
# Epoch 17/200
# 404/404 [==============] : loss = 75.32782011393223
# Epoch 18/200
# 404/404 [==============] : loss = 69.25657589164403
# Epoch 19/200
# 404/404 [==============] : loss = 63.778724003186525
# Epoch 20/200
# 404/404 [==============] : loss = 58.83564319074241
# Epoch 21/200
# 404/404 [==============] : loss = 54.374694982840026
# Epoch 22/200
# 404/404 [==============] : loss = 50.34853896836635
# Epoch 23/200
# 404/404 [==============] : loss = 46.71455506174257
# Epoch 24/200
# 404/404 [==============] : loss = 43.43434612731182
# Epoch 25/200
# 404/404 [==============] : loss = 40.473303480403466
# Epoch 26/200
# 404/404 [==============] : loss = 37.800223385971
# Epoch 27/200
# 404/404 [==============] : loss = 35.386966154122646
# Epoch 28/200
# 404/404 [==============] : loss = 33.20815163202218
# Epoch 29/200
# 404/404 [==============] : loss = 31.2408863185824
# Epoch 30/200
# 404/404 [==============] : loss = 29.464518283775934
# Epoch 31/200
# 404/404 [==============] : loss = 27.860416738827606
# Epoch 32/200
# 404/404 [==============] : loss = 26.41177358546826
# Epoch 33/200
# 404/404 [==============] : loss = 25.103424637255237
# Epoch 34/200
# 404/404 [==============] : loss = 23.92168849345474
# Epoch 35/200
# 404/404 [==============] : loss = 22.85422128054375
# Epoch 36/200
# 404/404 [==============] : loss = 21.889885673219865
# Epoch 37/200
# 404/404 [==============] : loss = 21.018632775562754
# Epoch 38/200
# 404/404 [==============] : loss = 20.231395589967185
# Epoch 39/200
# 404/404 [==============] : loss = 19.519992930910693
# Epoch 40/200
# 404/404 [==============] : loss = 18.877042755504053
# Epoch 41/200
# 404/404 [==============] : loss = 18.2958839852768
# Epoch 42/200
# 404/404 [==============] : loss = 17.77050598543215
# Epoch 43/200
# 404/404 [==============] : loss = 17.295484950185706
# Epoch 44/200
# 404/404 [==============] : loss = 16.865926516859044
# Epoch 45/200
# 404/404 [==============] : loss = 16.477413998047123
# Epoch 46/200
# 404/404 [==============] : loss = 16.12596168119877
# Epoch 47/200
# 404/404 [==============] : loss = 15.8079726990285
# Epoch 48/200
# 404/404 [==============] : loss = 15.520201022918844
# Epoch 49/200
# 404/404 [==============] : loss = 15.259717175410893
# Epoch 50/200
# 404/404 [==============] : loss = 15.02387729749694
# Epoch 51/200
# 404/404 [==============] : loss = 14.81029524215068
# Epoch 52/200
# 404/404 [==============] : loss = 14.616817397743304
# Epoch 53/200
# 404/404 [==============] : loss = 14.44149997404357
# Epoch 54/200
# 404/404 [==============] : loss = 14.282588509698757
# Epoch 55/200
# 404/404 [==============] : loss = 14.138499383720895
# Epoch 56/200
# 404/404 [==============] : loss = 14.007803134812681
# Epoch 57/200
# 404/404 [==============] : loss = 13.889209411586972
# Epoch 58/200
# 404/404 [==============] : loss = 13.781553394068318
# Epoch 59/200
# 404/404 [==============] : loss = 13.683783542499919
# Epoch 60/200
# 404/404 [==============] : loss = 13.594950543581144
# Epoch 61/200
# 404/404 [==============] : loss = 13.514197336980192
# Epoch 62/200
# 404/404 [==============] : loss = 13.440750116439064
# Epoch 63/200
# 404/404 [==============] : loss = 13.373910210136003
# Epoch 64/200
# 404/404 [==============] : loss = 13.3130467543047
# Epoch 65/200
# 404/404 [==============] : loss = 13.25759008252865
# Epoch 66/200
# 404/404 [==============] : loss = 13.20702576072358
# Epoch 67/200
# 404/404 [==============] : loss = 13.160889204670987
# Epoch 68/200
# 404/404 [==============] : loss = 13.11876082314524
# Epoch 69/200
# 404/404 [==============] : loss = 13.080261635250457
# Epoch 70/200
# 404/404 [==============] : loss = 13.045049315611498
# Epoch 71/200
# 404/404 [==============] : loss = 13.012814625598981
# Epoch 72/200
# 404/404 [==============] : loss = 12.983278192859574
# Epoch 73/200
# 404/404 [==============] : loss = 12.95618760511377
# Epoch 74/200
# 404/404 [==============] : loss = 12.931314787512738
# Epoch 75/200
# 404/404 [==============] : loss = 12.90845363584924
# Epoch 76/200
# 404/404 [==============] : loss = 12.887417880627394
# Epoch 77/200
# 404/404 [==============] : loss = 12.868039159439977
# Epoch 78/200
# 404/404 [==============] : loss = 12.850165277307356
# Epoch 79/200
# 404/404 [==============] : loss = 12.833658636621154
# Epoch 80/200
# 404/404 [==============] : loss = 12.818394820130523
# Epoch 81/200
# 404/404 [==============] : loss = 12.804261312027833
# Epoch 82/200
# 404/404 [==============] : loss = 12.791156343651219
# Epoch 83/200
# 404/404 [==============] : loss = 12.778987851639132
# Epoch 84/200
# 404/404 [==============] : loss = 12.767672537560937
# Epoch 85/200
# 404/404 [==============] : loss = 12.757135019120025
# Epoch 86/200
# 404/404 [==============] : loss = 12.747307063993656
# Epoch 87/200
# 404/404 [==============] : loss = 12.7381268982467
# Epoch 88/200
# 404/404 [==============] : loss = 12.729538582044144
# Epoch 89/200
# 404/404 [==============] : loss = 12.72149144609783
# Epoch 90/200
# 404/404 [==============] : loss = 12.713939582923999
# Epoch 91/200
# 404/404 [==============] : loss = 12.706841387566845
# Epoch 92/200
# 404/404 [==============] : loss = 12.700159142964997
# Epoch 93/200
# 404/404 [==============] : loss = 12.693858645608959
# Epoch 94/200
# 404/404 [==============] : loss = 12.687908867562289
# Epoch 95/200
# 404/404 [==============] : loss = 12.682281651302734
# Epoch 96/200
# 404/404 [==============] : loss = 12.676951434185447
# Epoch 97/200
# 404/404 [==============] : loss = 12.671894999642415
# Epoch 98/200
# 404/404 [==============] : loss = 12.66709125251403
# Epoch 99/200
# 404/404 [==============] : loss = 12.662521016162662
# Epoch 100/200
# 404/404 [==============] : loss = 12.65816684924743
# Epoch 101/200
# 404/404 [==============] : loss = 12.654012880246304
# Epoch 102/200
# 404/404 [==============] : loss = 12.650044657998308
# Epoch 103/200
# 404/404 [==============] : loss = 12.646249016707007
# Epoch 104/200
# 404/404 [==============] : loss = 12.642613953998579
# Epoch 105/200
# 404/404 [==============] : loss = 12.63912852076477
# Epoch 106/200
# 404/404 [==============] : loss = 12.635782721644972
# Epoch 107/200
# 404/404 [==============] : loss = 12.632567425113253
# Epoch 108/200
# 404/404 [==============] : loss = 12.62947428223693
# Epoch 109/200
# 404/404 [==============] : loss = 12.626495653264312
# Epoch 110/200
# 404/404 [==============] : loss = 12.623624541281307
# Epoch 111/200
# 404/404 [==============] : loss = 12.620854532250533
# Epoch 112/200
# 404/404 [==============] : loss = 12.618179740813565
# Epoch 113/200
# 404/404 [==============] : loss = 12.615594761297224
# Epoch 114/200
# 404/404 [==============] : loss = 12.61309462341913
# Epoch 115/200
# 404/404 [==============] : loss = 12.61067475223712
# Epoch 116/200
# 404/404 [==============] : loss = 12.608330931931146
# Epoch 117/200
# 404/404 [==============] : loss = 12.606059273046638
# Epoch 118/200
# 404/404 [==============] : loss = 12.603856182864023
# Epoch 119/200
# 404/404 [==============] : loss = 12.601718338592145
# Epoch 120/200
# 404/404 [==============] : loss = 12.599642663112274
# Epoch 121/200
# 404/404 [==============] : loss = 12.597626303026331
# Epoch 122/200
# 404/404 [==============] : loss = 12.595666608786674
# Epoch 123/200
# 404/404 [==============] : loss = 12.5937611167065
# Epoch 124/200
# 404/404 [==============] : loss = 12.591907532669458
# Epoch 125/200
# 404/404 [==============] : loss = 12.590103717374655
# Epoch 126/200
# 404/404 [==============] : loss = 12.588347672969126
# Epoch 127/200
# 404/404 [==============] : loss = 12.586637530934246
# Epoch 128/200
# 404/404 [==============] : loss = 12.584971541105444
# Epoch 129/200
# 404/404 [==============] : loss = 12.583348061716377
# Epoch 130/200
# 404/404 [==============] : loss = 12.581765550369152
# Epoch 131/200
# 404/404 [==============] : loss = 12.580222555841829
# Epoch 132/200
# 404/404 [==============] : loss = 12.578717710653002
# Epoch 133/200
# 404/404 [==============] : loss = 12.577249724310947
# Epoch 134/200
# 404/404 [==============] : loss = 12.575817377181982
# Epoch 135/200
# 404/404 [==============] : loss = 12.574419514918926
# Epoch 136/200
# 404/404 [==============] : loss = 12.57305504339618
# Epoch 137/200
# 404/404 [==============] : loss = 12.57172292410334
# Epoch 138/200
# 404/404 [==============] : loss = 12.570422169953652
# Epoch 139/200
# 404/404 [==============] : loss = 12.569151841468027
# Epoch 140/200
# 404/404 [==============] : loss = 12.567911043298976
# Epoch 141/200
# 404/404 [==============] : loss = 12.566698921062391
# Epoch 142/200
# 404/404 [==============] : loss = 12.56551465844809
# Epoch 143/200
# 404/404 [==============] : loss = 12.564357474582897
# Epoch 144/200
# 404/404 [==============] : loss = 12.563226621622517
# Epoch 145/200
# 404/404 [==============] : loss = 12.562121382550771
# Epoch 146/200
# 404/404 [==============] : loss = 12.561041069166846
# Epoch 147/200
# 404/404 [==============] : loss = 12.559985020242943
# Epoch 148/200
# 404/404 [==============] : loss = 12.558952599836585
# Epoch 149/200
# 404/404 [==============] : loss = 12.55794319574319
# Epoch 150/200
# 404/404 [==============] : loss = 12.556956218075978
# Epoch 151/200
# 404/404 [==============] : loss = 12.55599109796148
# Epoch 152/200
# 404/404 [==============] : loss = 12.55504728634004
# Epoch 153/200
# 404/404 [==============] : loss = 12.554124252861769
# Epoch 154/200
# 404/404 [==============] : loss = 12.553221484869207
# Epoch 155/200
# 404/404 [==============] : loss = 12.552338486458877
# Epoch 156/200
# 404/404 [==============] : loss = 12.551474777614615
# Epoch 157/200
# 404/404 [==============] : loss = 12.550629893406235
# Epoch 158/200
# 404/404 [==============] : loss = 12.549803383247705
# Epoch 159/200
# 404/404 [==============] : loss = 12.548994810209562
# Epoch 160/200
# 404/404 [==============] : loss = 12.54820375038079
# Epoch 161/200
# 404/404 [==============] : loss = 12.547429792275778
# Epoch 162/200
# 404/404 [==============] : loss = 12.546672536282541
# Epoch 163/200
# 404/404 [==============] : loss = 12.545931594148524
# Epoch 164/200
# 404/404 [==============] : loss = 12.545206588500848
# Epoch 165/200
# 404/404 [==============] : loss = 12.544497152398028
# Epoch 166/200
# 404/404 [==============] : loss = 12.543802928910543
# Epoch 167/200
# 404/404 [==============] : loss = 12.543123570727822
# Epoch 168/200
# 404/404 [==============] : loss = 12.542458739789447
# Epoch 169/200
# 404/404 [==============] : loss = 12.541808106938644
# Epoch 170/200
# 404/404 [==============] : loss = 12.541171351596196
# Epoch 171/200
# 404/404 [==============] : loss = 12.540548161453183
# Epoch 172/200
# 404/404 [==============] : loss = 12.539938232180996
# Epoch 173/200
# 404/404 [==============] : loss = 12.539341267157395
# Epoch 174/200
# 404/404 [==============] : loss = 12.538756977207209
# Epoch 175/200
# 404/404 [==============] : loss = 12.538185080356696
# Epoch 176/200
# 404/404 [==============] : loss = 12.537625301600462
# Epoch 177/200
# 404/404 [==============] : loss = 12.537077372680033
# Epoch 178/200
# 404/404 [==============] : loss = 12.536541031873233
# Epoch 179/200
# 404/404 [==============] : loss = 12.536016023793577
# Epoch 180/200
# 404/404 [==============] : loss = 12.535502099199
# Epoch 181/200
# 404/404 [==============] : loss = 12.534999014809204
# Epoch 182/200
# 404/404 [==============] : loss = 12.534506533131145
# Epoch 183/200
# 404/404 [==============] : loss = 12.534024422292015
# Epoch 184/200
# 404/404 [==============] : loss = 12.533552455879276
# Epoch 185/200
# 404/404 [==============] : loss = 12.533090412787269
# Epoch 186/200
# 404/404 [==============] : loss = 12.532638077070013
# Epoch 187/200
# 404/404 [==============] : loss = 12.532195237799776
# Epoch 188/200
# 404/404 [==============] : loss = 12.531761688931088
# Epoch 189/200
# 404/404 [==============] : loss = 12.531337229169857
# Epoch 190/200
# 404/404 [==============] : loss = 12.530921661847316
# Epoch 191/200
# 404/404 [==============] : loss = 12.530514794798508
# Epoch 192/200
# 404/404 [==============] : loss = 12.53011644024506
# Epoch 193/200
# 404/404 [==============] : loss = 12.529726414682
# Epoch 194/200
# 404/404 [==============] : loss = 12.529344538768456
# Epoch 195/200
# 404/404 [==============] : loss = 12.528970637221942
# Epoch 196/200
# 404/404 [==============] : loss = 12.528604538716165
# Epoch 197/200
# 404/404 [==============] : loss = 12.528246075782048
# Epoch 198/200
# 404/404 [==============] : loss = 12.527895084711963
# Epoch 199/200
# 404/404 [==============] : loss = 12.527551405466857
# Epoch 200/200
# 404/404 [==============] : loss = 12.527214881586309

# %%
plt.plot(model.loss_per_epochs)
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Training Loss')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
min(model.loss_per_epochs)
# Out:
# 12.527214881586309

# %%
model.get_weights()
# Out:
# {'weights': array([-0.5558, -0.1108, -1.7219,  2.915 , -0.058 , -2.6376, -2.0205,
#          0.7237, -3.8982]),
#  'bias': 22.39417522772399}

# %%
indices = np.random.permutation(np.arange(X_train.shape[0]))[:100]
y_pred = model.predict(X_train[indices, :])
y_true = y_train[indices]

# %%
plt.figure(figsize=(20,5))
plt.plot(y_true, 'b', lw=2.5, label='ground truth')
plt.plot(y_pred, 'c', lw=2.5, label='predictions')
plt.legend(loc='best')

# %%
weights, bias, mean, std = model.get_weights(return_scaling_params=True).values()
plt.figure(figsize=(20, 18))
X = (X_train - mean) / (std + 1e-9)
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.scatter(X[:, i], y_train, c='c', ec='k')
    y_pred = weights[i] * X[:, i] + bias
    plt.plot(X[:, i], y_pred, c='r', lw=2.5)
    plt.xlabel(f'X{i + 1}')
    plt.ylabel('y')

# %% [markdown]
# ## Evaluation

# %%
model.evaluate(X_test, y_test)
# Out:
# 9.863449051937613

# %%
y_pred = model.predict(X_test)

# %%
test_loss = 0.5 * np.mean((y_pred - y_test) ** 2)
print('test loss : ', test_loss)
# Out:
# test loss :  9.863449051937613

# %%
plt.figure(figsize=(20,5))
plt.plot(y_test, 'b', lw=2.5, label='ground truth')
plt.plot(y_pred, 'c', lw=2.5, label='predictions')
plt.legend(loc='best')

# %%
weights, bias, mean, std = model.get_weights(return_scaling_params=True).values()
plt.figure(figsize=(20, 18))
X = (X_test - mean) / (std + 1e-9)
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.scatter(X[:, i], y_test, c='c', ec='k')
    y_pred = weights[i] * X[:, i] + bias
    plt.plot(X[:, i], y_pred, c='r', lw=2.5)
    plt.xlabel(f'X{i + 1}')
    plt.ylabel('y')

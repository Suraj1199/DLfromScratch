# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# %%
np.set_printoptions(threshold=10)

# %% [markdown]
# ## Generating Univariate Data

# %%
np.random.RandomState(seed=11)
w = np.random.randn(1) * 10
b = np.random.randn(1) * 100
noise = np.random.randn(500) * np.random.randint(0, 25, 500)

# %%
x = np.random.permutation(np.linspace(-10, 10, 1000)[:-500])
y = w * x + b + noise

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Simple Linear Regression Model

# %%
class LinearRegressor:
    def __init__(self):
        self.__weight = np.random.randn(1)
        self.__bias = np.zeros(1)
        self.loss_per_epochs = []
    def fit(self, x, y, epochs=1, batch_size=None, alpha=0.001, verbose=True):
        losses = []
        for i in range(epochs):
            y_pred = self.__weight * x + self.__bias
            J = 0.5 * np.mean(np.square(y - y_pred), axis=-1)
            self.__weight -= alpha * np.mean((y_pred - y) * x)
            self.__bias -= alpha * np.mean(y_pred - y)
            losses.append(J)
            if verbose:
                print(f'Epoch {i+1}/{epochs}\n{x.shape[0]}/{x.shape[0]} [==============] : loss - {J}')
        self.loss_per_epochs = losses
    def prediction_line(self, x, y):
        y_pred = self.__weight * x + self.__bias
        plt.scatter(x, y, c='c', ec='k')
        plt.plot(x, y_pred, 'r', lw=3)
    def get_weights(self):
        return self.__weight, self.__bias

# %% [markdown]
# ## Training and Evaluation

# %%
model = LinearRegressor()

# %%
model.fit(x, y, epochs=10, alpha = 0.01)
# Out:
# Epoch 1/10
# 500/500 [==============] : loss - 4687.195467469317
# Epoch 2/10
# 500/500 [==============] : loss - 3003.965406138133
# Epoch 3/10
# 500/500 [==============] : loss - 2269.728603292552
# Epoch 4/10
# 500/500 [==============] : loss - 1946.948288740463
# Epoch 5/10
# 500/500 [==============] : loss - 1802.5760772777144
# Epoch 6/10
# 500/500 [==============] : loss - 1735.5740770400423
# Epoch 7/10
# 500/500 [==============] : loss - 1702.137352492994
# Epoch 8/10
# 500/500 [==============] : loss - 1683.2742329102448
# Epoch 9/10
# 500/500 [==============] : loss - 1670.7508026511332
# Epoch 10/10
# 500/500 [==============] : loss - 1660.9971555285615

# %%
plt.plot(model.loss_per_epochs)

# %%
model.prediction_line(x, y)

# %% [markdown]
# ## Improving Model Performance

# %%
model.fit(x, y, epochs=1000, alpha = 0.01, verbose=False)

# %%
plt.plot(model.loss_per_epochs)

# %%
min(model.loss_per_epochs)
# Out:
# 109.65139356632757

# %%
model.prediction_line(x, y)

# %% [markdown]
# # Comparing with Tensorflow Model

# %%
test_model = tf.keras.Sequential([tf.keras.layers.Input(shape=(1,)), tf.keras.layers.Dense(1)])
# Out:
# Metal device set to: Apple M1
# 2022-01-03 13:02:55.271502: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-03 13:02:55.271590: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
test_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.01), 
                   loss='mse', metrics='mse')

# %%
history = test_model.fit(x, y, epochs=100, batch_size=1, verbose=0)
# Out:
# 2022-01-03 13:02:55.326449: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-01-03 13:02:55.391973: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
plt.plot(history.history['loss'])

# %%
w, b = test_model.get_weights()
model.weight, model.bias = w.reshape(1), b
model.prediction_line(x, y)
